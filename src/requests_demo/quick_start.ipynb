# %%
import requests

# %%
r = requests.get("https://api.github.com/events")

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# '[{"id":"20895450944","type":"ReleaseEvent","actor":{"id":94171153,"login":"breakermind","display_login":"breakermind","gravatar_id":"","url":"https://api.github.com/users/breakermind","avatar_url":"https://avatars.githubusercontent.com/u/94171153?"},"repo":{"id":470656169,"name":"breakermind/pay","url":"https://api.github.com/repos/breakermind/pay"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/breakermind/pay/releases/62585072","assets_url":"https://api.github.com/repos/breakermind/pay/releases/62585072/assets","upload_url":"https://uploads.github.com/repos/breakermind/pay/releases/62585072/assets{?name,label}","html_url":"https://github.com/breakermind/pay/releases/tag/v2.0.1","id":62585072,"author":{"login":"breakermind","id":94171153,"node_id":"U_kgDOBZzwEQ","avatar_url":"https://avatars.githubusercontent.com/u/94171153?v=4","gravatar_id":"","url":"https://api.github.com/users/breakermind","html_url":"https://github.com/breakermind","followers_url":"https://api.github.com/users/breakermind/followers","following_url":"https://api.github.com/users/breakermind/following{/other_user}","gists_url":"https://api.github.com/users/breakermind/gists{/gist_id}","starred_url":"https://api.github.com/users/breakermind/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/breakermind/subscriptions","organizations_url":"https://api.github.com/users/breakermind/orgs","repos_url":"https://api.github.com/users/breakermind/repos","events_url":"https://api.github.com/users/breakermind/events{/privacy}","received_events_url":"https://api.github.com/users/breakermind/received_events","type":"User","site_admin":false},"node_id":"RE_kwDOHA2kqc4Duvjw","tag_name":"v2.0.1","target_commitish":"main","name":"Php PayU payments in Laravel","draft":false,"prerelease":false,"created_at":"2022-03-23T14:12:53Z","published_at":"2022-03-23T14:32:46Z","assets":[],"tarball_url":"https://api.github.com/repos/breakermind/pay/tarball/v2.0.1","zipball_url":"https://api.github.com/repos/breakermind/pay/zipball/v2.0.1","body":"Payment handling for the Laravel application with PayU REST API.","short_description_html":"<p>Payment handling for the Laravel application with PayU REST API.</p>","is_short_description_html_truncated":false}},"public":true,"created_at":"2022-03-23T14:32:47Z"},{"id":"20895439448","type":"PushEvent","actor":{"id":30577764,"login":"otmanLAHRECHE","display_login":"otmanLAHRECHE","gravatar_id":"","url":"https://api.github.com/users/otmanLAHRECHE","avatar_url":"https://avatars.githubusercontent.com/u/30577764?"},"repo":{"id":465353366,"name":"otmanLAHRECHE/EPSP_Garde_Project","url":"https://api.github.com/repos/otmanLAHRECHE/EPSP_Garde_Project"},"payload":{"push_id":9427454988,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"26205ab4b0b7e8a68104c6bd6006f5930036a63a","before":"21cc93a82f86181c0fa643ae797bf4d1c7e56a7f","commits":[{"sha":"26205ab4b0b7e8a68104c6bd6006f5930036a63a","author":{"email":"laotman.47@gmail.com","name":"Otman LAHRECHE"},"message":"important updates","distinct":true,"url":"https://api.github.com/repos/otmanLAHRECHE/EPSP_Garde_Project/commits/26205ab4b0b7e8a68104c6bd6006f5930036a63a"}]},"public":true,"created_at":"2022-03-23T14:32:17Z"},{"id":"20895439477","type":"CreateEvent","actor":{"id":38760734,"login":"yakkomajuri","display_login":"yakkomajuri","gravatar_id":"","url":"https://api.github.com/users/yakkomajuri","avatar_url":"https://avatars.githubusercontent.com/u/38760734?"},"repo":{"id":235901813,"name":"PostHog/posthog","url":"https://api.github.com/repos/PostHog/posthog"},"payload":{"ref":"nuke-protobuf-pt1","ref_type":"branch","master_branch":"master","description":"🦔 PostHog provides open-source product analytics that you can self-host. ","pusher_type":"user"},"public":true,"created_at":"2022-03-23T14:32:17Z","org":{"id":60330232,"login":"PostHog","gravatar_id":"","url":"https://api.github.com/orgs/PostHog","avatar_url":"https://avatars.githubusercontent ...
